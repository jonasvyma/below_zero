# %%
import pandas as pd
from sqlalchemy import create_engine, types
from sqlalchemy import text # to be able to pass string

# %%
from datetime import datetime
from meteostat import Hourly
import pandas as pd

start = datetime(2005, 7, 23)
end   = datetime(2005, 9, 23) 
loc   = '72202'                

data = Hourly(loc, start, end, timezone='America/New_York').fetch()
data.reset_index().to_csv("miami_2months_hourly.csv", index=False)
print("Saved -> miami_MIA_2005-08-23_hourly.csv")
# Out:
# Saved -> miami_MIA_2005-08-23_hourly.csv

# %%
weather_daily_df = pd.DataFrame(data)
weather_daily_df
# Out:
#                            temp  dwpt  rhum  prcp  snow   wdir  wspd  wpgt  \
# time
# 2005-07-23 00:00:00-04:00  29.4  24.9  77.0   0.0  <NA>  220.0  11.2  <NA>
# 2005-07-23 01:00:00-04:00  28.9  25.1  80.0   0.0  <NA>  250.0   9.4  <NA>
# 2005-07-23 02:00:00-04:00  28.9  25.1  80.0   0.0  <NA>  250.0   5.4  <NA>
# 2005-07-23 03:00:00-04:00  28.9  25.5  82.0   0.0  <NA>  280.0   5.4  <NA>
# 2005-07-23 04:00:00-04:00  28.9  25.5  82.0   0.0  <NA>  270.0   7.6  <NA>
# ...                         ...   ...   ...   ...   ...    ...   ...   ...
# 2005-09-22 20:00:00-04:00  28.9  25.5  82.0   0.0  <NA>   90.0  18.4  <NA>
# 2005-09-22 21:00:00-04:00  25.6  24.4  93.0   0.8  <NA>  150.0  22.3  <NA>
# 2005-09-22 22:00:00-04:00  26.1  24.0  88.0   1.0  <NA>  100.0   9.4  <NA>
# 2005-09-22 23:00:00-04:00  25.6  24.4  93.0   0.8  <NA>  110.0  22.3  <NA>
# 2005-09-23 00:00:00-04:00  25.6  23.3  87.0   0.0  <NA>  110.0  22.3  <NA>
#
#                              pres  tsun  coco
# time
# ...

# %%
start = datetime(2005, 7, 23)
end   = datetime(2005, 9, 23) 
loc   = '72231'                

data_no = Hourly(loc, start, end, timezone='America/New_York').fetch()
data_no.reset_index().to_csv("new_orleans_2months_hourly.csv", index=False)
print("Saved -> new_orleans_2_months.csv")
# Out:
# Saved -> new_orleans_2_months.csv

# %%
weather_no_df = pd.DataFrame(data_no)
weather_no_df.head()
# Out:
#                            temp  dwpt  rhum  prcp  snow   wdir  wspd  wpgt  \
# time
# 2005-07-23 00:00:00-04:00  27.2  23.9  82.0   0.0  <NA>  260.0  11.2  <NA>
# 2005-07-23 01:00:00-04:00  27.2  23.9  82.0   0.0  <NA>  230.0  11.2  <NA>
# 2005-07-23 02:00:00-04:00  26.7  23.4  82.0   0.0  <NA>  280.0   7.6  <NA>
# 2005-07-23 03:00:00-04:00  26.7  23.4  82.0   0.0  <NA>    0.0   0.0  <NA>
# 2005-07-23 04:00:00-04:00  26.7  23.4  82.0   0.0  <NA>  300.0   5.4  <NA>
#
#                              pres  tsun  coco
# time
# 2005-07-23 00:00:00-04:00  1018.3  <NA>  <NA>
# 2005-07-23 01:00:00-04:00  1018.5  <NA>  <NA>
# 2005-07-23 02:00:00-04:00  1018.4  <NA>  <NA>
# 2005-07-23 03:00:00-04:00  1018.3  <NA>  <NA>
# 2005-07-23 04:00:00-04:00  1018.1  <NA>  <NA>

# %%
start = datetime(2005, 7, 23)
end   = datetime(2005, 9, 23) 
loc   = '72223'                

data_mra = Hourly(loc, start, end, timezone='America/New_York').fetch()
data_mra.reset_index().to_csv("mobile_regional_airport_2months_hourly.csv", index=False)

# %%
weather_mra_df = pd.DataFrame(data_mra)
weather_mra_df.head()
# Out:
#                            temp  dwpt  rhum  prcp  snow   wdir  wspd  wpgt  \
# time
# 2005-07-23 00:00:00-04:00  26.7  23.4  82.0   0.0  <NA>  310.0   5.4  <NA>
# 2005-07-23 01:00:00-04:00  26.7  23.4  82.0   0.0  <NA>  240.0   7.6  <NA>
# 2005-07-23 02:00:00-04:00  26.1  24.0  88.0   0.0  <NA>  270.0   7.6  <NA>
# 2005-07-23 03:00:00-04:00  25.6  23.3  87.0   0.0  <NA>  290.0   5.4  <NA>
# 2005-07-23 04:00:00-04:00  25.6  23.3  87.0   0.0  <NA>  280.0   7.6  <NA>
#
#                              pres  tsun  coco
# time
# 2005-07-23 00:00:00-04:00  1018.2  <NA>  <NA>
# 2005-07-23 01:00:00-04:00  1018.2  <NA>  <NA>
# 2005-07-23 02:00:00-04:00  1018.1  <NA>  <NA>
# 2005-07-23 03:00:00-04:00  1017.7  <NA>  <NA>
# 2005-07-23 04:00:00-04:00  1017.4  <NA>  <NA>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# safer path string
xls_path = r"C:\Users\rizza\Desktop\gaussian_peppers\dbt_meteostat\below_zero\simone\weather data.xlsx"

# load all sheets
xls = pd.ExcelFile(xls_path)
dfs = [pd.read_excel(xls, sheet_name=s) for s in xls.sheet_names]

# combine into one dataframe
df = pd.concat(dfs, ignore_index=True)

# build a proper datetime column (choose your year, e.g. 2005)
YEAR = 2005
df["date"] = pd.to_datetime({
    "year": YEAR,
    "month": df["month"],
    "day": df["day"]
})

print(df.head())
# Out:
#   airport  month  day  wind_speed       date
# 0     MIA      7    1         9.0 2005-07-01
# 1     MIA      7    2         8.0 2005-07-02
# 2     MIA      7    3        11.0 2005-07-03
# 3     MIA      7    4        12.0 2005-07-04
# 4     MIA      7    5        16.0 2005-07-05

# %%
# define date window
start = pd.to_datetime("2005-08-10")
end   = pd.to_datetime("2005-09-10")

# filter for that period
period_df = df[(df["date"] >= start) & (df["date"] <= end)]

# plot
sns.set_theme()
plt.figure(figsize=(12,6))

sns.lineplot(
    data=period_df,
    x="date",
    y="wind_speed",
    hue="airport"
)

# vertical line at 23 August 2005
plt.axvline(pd.to_datetime("2005-08-23"), color="red", linestyle="--", linewidth=2, label="23 Aug 2005")

plt.title("Wind Speed — 10 Aug to 10 Sep 2005")
plt.xlabel("Date")
plt.ylabel("Wind Speed")
plt.legend(title="Airport")
plt.tight_layout()
plt.show()

# %%
df = pd.read_csv('prep_weather_hourly_202509151140.csv')
YEAR = 2005
df["date"] = pd.to_datetime({
    "year": YEAR,
    "month": df["month"],
    "day": df["day"]
})

print(df.head())
# Out:
#   airport_code  month  day  hour  temp_c  precipitation_mm  humidity_perc  \
# 0          MIA    7.0  1.0   0.0    26.1               NaN           90.0
# 1          MIA    7.0  1.0   1.0    26.7               0.0           87.0
# 2          MIA    7.0  1.0   2.0    25.6               2.0           93.0
# 3          MIA    7.0  1.0   3.0    25.6               0.3           90.0
# 4          MIA    7.0  1.0   4.0    25.6               NaN           93.0
#
#    pressure_hpa       date
# 0        1015.6 2005-07-01
# 1        1015.9 2005-07-01
# 2        1016.5 2005-07-01
# 3        1016.6 2005-07-01
# 4        1016.6 2005-07-01

# %%
# define narrower date window
start = pd.to_datetime("2005-08-20")
end   = pd.to_datetime("2005-08-31")

# filter
aug_window = df[(df["date"] >= start) & (df["date"] <= end)]

# plot
plt.figure(figsize=(12,6))
sns.lineplot(
    data=aug_window,
    x="date",
    y="precipitation_mm",
    hue="airport_code"        # make sure this matches your column name
)

# highlight 23 Aug
plt.axvline(pd.to_datetime("2005-08-23"), color="red", linestyle="--", linewidth=2, label="23 Aug 2005")

plt.title("Precipitation — 20 to 31 Aug 2005")
plt.xlabel("Date")
plt.ylabel("Precipitation (mm)")
plt.legend(title="Airport")
plt.tight_layout()
plt.show()
